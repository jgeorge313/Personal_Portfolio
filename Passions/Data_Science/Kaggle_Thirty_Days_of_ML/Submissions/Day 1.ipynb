# %% [markdown]
# # Day 1: Kaggle 30 days of ML:
#
# ## Titanic Challenge
#
# An introduction to Machine Learning, on the analytics platform, Kaggle.
#
# Given the input variables:
#
#     Passenger Seat Class (valid values:1st, 2nd, 3rd)
#     Sex
#     Age
#     siblings \ spouses in the Titanic
#     Ticket number
#     Passenger Fare
#     Cabin number
#     Port of Embarkation
#
# Predict which customers survive the Titanic shipwreck
#
# General Steps to complete this prediction challenge:
#
#      1. Read the Data
#      2. Data Exploration
#      3. Hypothesis generation -- which features do we believe will be most predictive of the task at hand
#      4. Model Creation
#      5. Model Selection \ Validation

# %% [markdown]
# ## Step 1: Reading the Data
#
#     First, we'll perform imports, using the default code that Kaggle provides
#     Second, we import additional packages that will be useful for the challenge
#     Third, we'll load the train + test data on Kaggle's

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train = pd.read_csv('/kaggle/input/titanic/train.csv')
test = pd.read_csv('/kaggle/input/titanic/test.csv')

train.head()

# %% [markdown]
# # Data Exploration:
#
# I'm interested in learning:
#
#         what relationships exist on a univariate basis with the Survived Status
#         which variables are multi-correlated
#
#
#
# Note to self: Review practices from ML \ BA at University of Virginia

# %%
table = pd.pivot_table(train,  index=['Pclass', 'Embarked'], values=['Survived'],
                     aggfunc= ['sum', 'count'])

#1 & 2 class is positively correlated in surviving
#3rd class embarking from S is a big decrease in odds

#dig deeper into the train data of 3rd class from S

# %%
sub_segment = train.loc[(train['Pclass'] == 3) & (train['Embarked'] == 'S')
                        ]
sub_segment_piv = pd.pivot_table(sub_segment, index=['Sex'], values=['Survived'],
                     aggfunc= ['sum', 'count'])

sub_segment_piv

## okay women in this segment had a much greater chance of survival, 
#but were there any indications a woman would not make it
